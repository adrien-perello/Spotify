# %%
# Standard libraries
import sys

# Scientific libraries
import pandas as pd

# Spotify
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import spotify_credentials

# Utility functions
from helpers.helpers_spotify import get_tracks_from_playlist, get_tracks_from_id, cleaned_track_data

# %%
def clear_spotify_cache():
    """Clears the Spotify API cache."""
    from helpers.helpers_spotify import clear_cache
    clear_cache()

# %% [markdown]
# # Import Spotify Data
#
# ## Identification

# %%
# read about scopes here: 
# https://developer.spotify.com/documentation/general/guides/authorization/scopes/#playlist-read-private

scope = "user-library-read"
spotify = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=spotify_credentials.client_ID, 
                                                client_secret= spotify_credentials.client_SECRET, 
                                                redirect_uri=spotify_credentials.redirect_url, 
                                                scope=scope,
                                                ),
                            requests_timeout=5,  # Tell Requests to stop waiting for a response after X seconds
                            retries=1,           # Total number of retries to allow
                            status_retries=3,    # Number of times to retry on bad status codes
                            backoff_factor=30,   # A backoff factor to apply between attempts after the second try
                        )

# %%
# Define the Spotify API scope for user library read access
# https://developer.spotify.com/documentation/general/guides/authorization/scopes/#playlist-read-private
spotify_scope = "user-library-read"

# Set up authentication with Spotify OAuth and API requests configuration
spotify_auth_manager = SpotifyOAuth(
    client_id=spotify_credentials.client_ID,
    client_secret=spotify_credentials.client_SECRET,
    redirect_uri=spotify_credentials.redirect_url,
    scope=spotify_scope
)

spotify_api = spotipy.Spotify(
    auth_manager=spotify_auth_manager,
    requests_timeout=5,   # Stop waiting for a response after X seconds
    retries=1,            # Total number of retries allowed
    status_retries=3,     # Number of times to retry on bad status codes
    backoff_factor=30     # Backoff factor to apply between attempts after the second try
)

# %% [markdown]
# ## Scrap saved tracks data

# %%
def get_saved_tracks(sp):
    """
    Retrieves the metadata for all saved tracks for the authenticated user from Spotify API.
    More info here: https://github.com/alicebarbe/SoundtrackofLife/blob/main/spotify.py
    
    Parameters:
    - sp: A Spotipy client object with authorized access to user's Spotify account.
    
    Returns:
    - A list of dictionaries containing the metadata for all saved tracks.
    """
    tracks = []
    results = sp.current_user_saved_tracks(limit=50)
    tracks.extend(results['items'])
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

# %%
def spotify_analyzer(data, spotipy_client):
    """
    Analyzes audio features of Spotify tracks and returns a pandas DataFrame.

    Parameters:
    -----------
    data : dict
        Dictionary with metadata of a Spotify playlist.
    spotipy_client : spotipy.Spotify
        A spotipy client object with valid authentication.

    Returns:
    --------
    pd.DataFrame
        A pandas DataFrame with audio features of tracks from the specified playlist.
    """
    
    # List of audio features to extract
    audio_keys = (
        "energy",
        "valence",
        "danceability",
        "acousticness",
        "danceability",
        "loudness",
        "speechiness",
        "instrumentalness",
        "liveness",
        "tempo",
        "key",
        "mode",
        "time_signature",
        "duration_ms",
    )

    # List to store extracted data
    music_data = []

    # Get a generator of tracks from the specified playlist
    track_generator = get_tracks_from_playlist(playlist_metadata=data)  # # when data is a dict
    # gen = get_tracks_from_id(tracks_id=data, spotipy_client=spotipy_client)  # when data is a list of id

    # Iterate over the tracks and extract audio features
    for i, track_metadata in enumerate(track_generator):
        # Display the track index
        sys.stdout.flush()
        print(f"Processing track #{i}")
        sys.stdout.flush()
        # Extract info about the track
        music_data.append(
            cleaned_track_data(
                track_metadata=track_metadata,
                audio_keys=audio_keys,
                spotipy_client=spotipy_client,
            )
        )

    # Return the extracted data as a pandas DataFrame
    return pd.DataFrame(music_data)

# %%
# Retrieve metadata for all saved tracks in a user's Spotify library 
playlist_metadata = get_saved_tracks(spotify)

# %%
# # PARALLEL PROCESS (MIGHT RUN INTO 'RATE LIMIT' BY SPOTIFY API)
# from joblib import Parallel, delayed
# results = Parallel(n_jobs=-1)(delayed(spotify_analyzer)(data, spotify) for data in playlist_metadata)
# df = pd.concat(results).reset_index(drop=True)

# # LINEAR PROCESS
df = spotify_analyzer(data=playlist_metadata, spotipy_client=spotify)
df
# Out:
# Processing track #0
# artist id:  5x183GdNFhX9FETwGNpOZE
# Processing track #1
# artist id:  5Y1YwWzFX7BIxBbdAOXOEJ
# Processing track #2
# artist id:  49CZw9qooXeYTWKe9ioZPx
# Processing track #3
# artist id:  65orViGnlMcbptdIGceZzo
# Processing track #4
# artist id:  21mKp7DqtSNHhCAU2ugvUw
# artist id:  238y1dKPtMeFEpX3Y6H1Vr
# artist id:  7E3BRXV9ZbCt5lQTCXMTia
# Processing track #5
# artist id:  238y1dKPtMeFEpX3Y6H1Vr
# Processing track #6
# artist id:  6ghG9s4GfKVwxKtSdCtgwP
# artist id:  36C73GYwgP8rqwCjUyswoS
# Processing track #7
# artist id:  6bkF6GDcyXZn2T0D5Fwldl
# Processing track #8
# artist id:  4e8ExN8iJrXnycI51N1Cxb
# genres = []
# Processing track #9
# artist id:  1xYnhHUchQSdNUiAFj1UFI
# genres = []
# Processing track #10
# artist id:  7C3Cbtr2PkH2l4tOGhtCsk
# Processing track #11
# artist id:  2QU3bcawUYfHbcPmWPHtra
# Processing track #12
# artist id:  7D5oTJSXSHf51auG0106CQ
# Processing track #13
# artist id:  68w2xQfXKCqxrRoDkhGtyp
# Processing track #14
# artist id:  10jkdLoGCp06EB8vIRKAWO
# genres = []
# Processing track #15
# artist id:  2IPZPCen311aH09425TKpF
# Processing track #16
# artist id:  1NWjumiUC54F8S21p2W6cG
# Processing track #17
# artist id:  4yyre4wV5as2rW3k0gekFA
# Processing track #18
# artist id:  0Q4xsA5aPdcrmxepPGP0x6
# Processing track #19
# artist id:  37J1PlAkhRK7yrZUtqaUpQ
# Processing track #20
# artist id:  37J1PlAkhRK7yrZUtqaUpQ
# Processing track #21
# artist id:  37J1PlAkhRK7yrZUtqaUpQ
# Processing track #22
# artist id:  1Co2g2ed1VfT3MFeaAEZDI
# genres = []
# artist id:  2LmUfQ0pBNCK9xFIJoO17J
# genres = []
# Processing track #23
# artist id:  7qJHwvMJBW2Da8kt79uexr
# genres = []
# Processing track #24
# artist id:  5tDjiBYUsTqzd0RkTZxK7u
# genres = []
# Processing track #25
# artist id:  3Ju2hEmz5onAzHRpy4tXe6
# Processing track #26
# artist id:  2ABEVwxsESCBsCBjN6qFru
# Processing track #27
# artist id:  46pzwQbaXoRtHMvl1NtIwB
# Processing track #28
# artist id:  6E8vZ5lkpXbXlkgHhbVJSl
# artist id:  1I7FVmvisCtSFzmm87mbLR
# Processing track #29
# artist id:  2AyLrA3GFbgbrjOjVnGcny
# Processing track #30
# artist id:  7sTCF1oPEvu9dWonIAcX5a
# genres = []
# Processing track #31
# artist id:  2i9OpWjVeuDPilnZ0mgM1L
# genres = []
# Processing track #32
# artist id:  4jGpKAmwvU263l0tUh4xKU
# Processing track #33
# artist id:  0RaR5kDG6RThEm7WOgpLO9
# Processing track #34
# artist id:  2DuNm4y5XDTQuFqIgv8rZP
# genres = []
# Processing track #35
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #36
# artist id:  5z2De8UDjNsituyyJOXh8H
# artist id:  5cVZnnikhcTwPENYemDKF6
# Processing track #37
# artist id:  0CLRpcHXiZS33XwebzMZ6B
# Processing track #38
# artist id:  3aCeGV6F1d9QwfYOpOtJOn
# genres = []
# Processing track #39
# artist id:  1HNzOuRGvIWVIMTp1B7PSg
# genres = []
# artist id:  3I6e2ZqqoxQhXc9z7Tp5ci
# artist id:  6bkF6GDcyXZn2T0D5Fwldl
# Processing track #40
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #41
# artist id:  1CsZ0ihKPWBDUERlQt8ekr
# Processing track #42
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #43
# artist id:  5vDfVxwAH8ANpuIKKxfOeq
# artist id:  7o2FMy3ZI4GssMyY8ELHGt
# Processing track #44
# artist id:  1I7FVmvisCtSFzmm87mbLR
# Processing track #45
# artist id:  0F1wth3t5bL0Vdjuk34yMP
# artist id:  3yu4VilcxpQ6h35vRcemBp
# Processing track #46
# artist id:  0FNLrVKyvRdifc0MHYnl8x
# Processing track #47
# artist id:  7fLHLIzQkhIOqrotQlR1rA
# Processing track #48
# artist id:  2AawTjX2X63z0FkI0BdLIA
# Processing track #49
# artist id:  4k8ZMbCLduQVguxDIJgDse
# Processing track #50
# artist id:  6p48WwMmjnyuDphnW3KUlb
# Processing track #51
# artist id:  1TTO5SuWJWgnOOGMdwVvD5
# Processing track #52
# artist id:  5sPMTZypbBMh5mAdIFcuMA
# artist id:  4BYqP4YTwWGpi4q94QkW2x
# Processing track #53
# artist id:  2WdxgHMgsowBao1uQT0lRa
# Processing track #54
# artist id:  2ZQinGoK9FA6ohO68q65A5
# Processing track #55
# artist id:  4TFmgYfhLJxF6nL8WDSnWV
# Processing track #56
# artist id:  4yDQsYGzevEpvJ9wfCCgkf
# Processing track #57
# artist id:  7zLDabVhJXJvgPMaVIsW3G
# artist id:  70ydBDjfOUaerv2i50ABrW
# genres = []
# Processing track #58
# artist id:  29osCpAsrEiHxE8t6khiJr
# artist id:  3UTSd6KiWqSG524qzbeunC
# genres = []
# artist id:  7cXcfKj2SStMqO7TIcwUSF
# genres = []
# Processing track #59
# artist id:  3Iz56wuRMuAVBmBWFkNMKI
# genres = []
# Processing track #60
# artist id:  7CUmdcvfZJrSsg4jnNNwHA
# Processing track #61
# artist id:  2ZQinGoK9FA6ohO68q65A5
# Processing track #62
# artist id:  5uRjAC3iCZSiWIcloRW1yV
# genres = []
# Processing track #63
# artist id:  5yQKbxLaJf3El246S0Lm9U
# artist id:  6jRfMO42wg0IQ6RttujxFp
# genres = []
# artist id:  6SdS8XN5V0Glu8Fo2sXwfX
# genres = []
# Processing track #64
# artist id:  0142LFmMLrdw3PWx8yCo3X
# Processing track #65
# artist id:  5S99ZV4z8f1cQpoqm22ZB9
# Processing track #66
# artist id:  29osCpAsrEiHxE8t6khiJr
# artist id:  3iZz7AYSS8RDAIhZUaZ4ez
# genres = []
# Processing track #67
# artist id:  2AyLrA3GFbgbrjOjVnGcny
# Processing track #68
# artist id:  5S99ZV4z8f1cQpoqm22ZB9
# Processing track #69
# artist id:  5S99ZV4z8f1cQpoqm22ZB9
# Processing track #70
# artist id:  3e60RbgzDP7TN7UV7LRGEJ
# artist id:  3A7HeGBIImzVJmlY2odYMB
# genres = []
# Processing track #71
# artist id:  5uRjAC3iCZSiWIcloRW1yV
# genres = []
# Processing track #72
# artist id:  2AyLrA3GFbgbrjOjVnGcny
# Processing track #73
# artist id:  2AyLrA3GFbgbrjOjVnGcny
# Processing track #74
# artist id:  2AyLrA3GFbgbrjOjVnGcny
# Processing track #75
# artist id:  2AyLrA3GFbgbrjOjVnGcny
# Processing track #76
# artist id:  2AyLrA3GFbgbrjOjVnGcny
# Processing track #77
# artist id:  2AyLrA3GFbgbrjOjVnGcny
# artist id:  238y1dKPtMeFEpX3Y6H1Vr
# Processing track #78
# artist id:  0fZ2s0I6Gyt60JUJybaEZA
# Processing track #79
# artist id:  1xR6udumbq1hdmMeTKgLUz
# Processing track #80
# artist id:  4igGvshE0R9UvpobsKOsSK
# Processing track #81
# artist id:  62Jwsvqi7hW8TR9rAcfBXY
# Processing track #82
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #83
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #84
# artist id:  1wq0c9TGASSeshO6QzdTF5
# genres = []
# Processing track #85
# artist id:  4OvLy4oD9IFQ8YCbbMDVRD
# Processing track #86
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #87
# artist id:  62Jwsvqi7hW8TR9rAcfBXY
# Processing track #88
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #89
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# artist id:  06tYi7DxoKe8PfYCeHGGFK
# genres = []
# Processing track #90
# artist id:  4dTw5svKFBPnfijbi3H9eI
# Processing track #91
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #92
# artist id:  2Iv8Ak5bq191xnSR9qSg6l
# Processing track #93
# artist id:  2iLMJdaqsQ44X7MPRD7rR5
# genres = []
# Processing track #94
# artist id:  1CsZ0ihKPWBDUERlQt8ekr
# Processing track #95
# artist id:  3UlxLrm4Nt8Ga2eLv4RoN2
# genres = []
# Processing track #96
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #97
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #98
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #99
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #100
# artist id:  4hSeosKw3pr72gC10igZow
# Processing track #101
# artist id:  1Gw0Q0Oyi46o9Qd5oOQuv9
# Processing track #102
# artist id:  238y1dKPtMeFEpX3Y6H1Vr
# artist id:  2AyLrA3GFbgbrjOjVnGcny
# Processing track #103
# artist id:  7rd8rHnXBEbrRCa6BZwJTH
# genres = []
# Processing track #104
# artist id:  0yWtq3VaXTns2rqmEdTGX8
# Processing track #105
# artist id:  1ILwJ5zliBLMsRARQJjOMp
# Processing track #106
# artist id:  08LrhaMKwKuGbB9XHBEjXF
# Processing track #107
# artist id:  6kv6jaS62CE2oWnH7msKzT
# genres = []
# Processing track #108
# artist id:  1jG7yqKlaLOoTEhheRCvHy
# Processing track #109
# artist id:  7oaQcTqp6TnWoCjNZRitki
# artist id:  5j3iObqG7iT7utWpTTmC7F
# Processing track #110
# artist id:  2ixyuVKle4CPPw7rwYAesG
# genres = []
# Processing track #111
# artist id:  4tNxq9NGKTKaX8OkZBLgf0
# Processing track #112
# artist id:  1OVwwL5UzympXO9NrpDUuY
# artist id:  1ncMwizQfpoqT5krZ89tZX
# genres = []
# Processing track #113
# artist id:  4NZM5xKuDpGc4vEHDwGO1Q
# Processing track #114
# artist id:  5NkUpXWkeXspvu7iQQOHhP
# Processing track #115
# artist id:  6KQ7zOmEoEm2tgJsoYq55x
# genres = []
# Processing track #116
# artist id:  3E6Tbv49KoKnCoGqHJHQGx
# Processing track #117
# artist id:  0KjF9pkI2bO9EMuB7LnHqP
# artist id:  1CsZ0ihKPWBDUERlQt8ekr
# Processing track #118
# artist id:  3wqjOyUcOsV0wSLgCsGwf4
# Processing track #119
# artist id:  1a4N2lwra7WGjwCDJS1Dkk
# Processing track #120
# artist id:  0XtVN1QaB7vYRpw4qEIRt0
# Processing track #121
# artist id:  1JSPpoXFLcEG2WhYlvmHPJ
# Processing track #122
# artist id:  6l0qnbpSfHw1vk6tQUquDt
# Processing track #123
# artist id:  6HzVTgf7SWVWNo93bT5TEv
# Processing track #124
# artist id:  4KZmpaIhanIo46eaQimtgO
# Processing track #125
# artist id:  2CtiNJi0zB35RHYXViVjKG
# genres = []
# Processing track #126
# artist id:  0nqq006Uo7RuKoKdmLAOkE
# genres = []
# Processing track #127
# artist id:  42IYQ7h5el8zcfEfS8zdMD
# Processing track #128
# artist id:  7aGBJiUws3qcoRhY2lUizy
# genres = []
# artist id:  1CsZ0ihKPWBDUERlQt8ekr
# Processing track #129
# artist id:  38MKhZmMRHAZRz8LqtKIBw
# Processing track #130
# artist id:  25OslGicPT7wGn5Ovf4Uwx
# Processing track #131
# artist id:  4o6gglPeg2GgT0FYDtzFeF
# artist id:  0zBxGJNVKeETQsG7prk6jR
# artist id:  52pEvBJxxzBacaaxVOSyxa
# Processing track #132
# artist id:  6QKXpRoHzASRPcty2agScr
# genres = []
# artist id:  2jvKLLBED6JvKWtT8y3kCu
# Processing track #133
# artist id:  2TkEAdH5xKTAPtpxBhyVyM
# genres = []
# artist id:  1iE0oaxCOpS6LXk3XzJ5va
# genres = []
# Processing track #134
# artist id:  40jQ2r3Sji04Pao0JxWGEd
# Processing track #135
# artist id:  2CIMQHirSU0MQqyYHq0eOx
# Processing track #136
# artist id:  29osCpAsrEiHxE8t6khiJr
# artist id:  3S1ElnphHMVO5GG4n5fKgv
# genres = []
# artist id:  2mTAbsYrWl42yCsMAhlVaR
# Processing track #137
# artist id:  0mXTJETA4XUa12MmmXxZJh
# Processing track #138
# artist id:  6wH6iStAh4KIaWfuhf0NYM
# Processing track #139
# artist id:  6wH6iStAh4KIaWfuhf0NYM
# Processing track #140
# artist id:  6wH6iStAh4KIaWfuhf0NYM
# Processing track #141
# artist id:  6jq7GptAwkoFiunDhZYqQ2
# Processing track #142
# artist id:  6wH6iStAh4KIaWfuhf0NYM
# Processing track #143
# artist id:  1fBcQOi8yEfWN7fknMoqIE
# Processing track #144
# artist id:  0uRdK8gy7fXJGRywrlmPM7
# Processing track #145
# artist id:  0uRdK8gy7fXJGRywrlmPM7
# Processing track #146
# artist id:  0uRdK8gy7fXJGRywrlmPM7
# Processing track #147
# artist id:  4Rj2COYs5hQsw8rYIxSviz
# Processing track #148
# artist id:  4tgBpjW0GVvKqP7uY2OHYB
# genres = []
# Processing track #149
# artist id:  6aPkORVtaipgr2ryrcNQRp
# Processing track #150
# artist id:  1CsZ0ihKPWBDUERlQt8ekr
# artist id:  5gsFX3cL4RcHWquOZwbWOK
# genres = []
# Processing track #151
# artist id:  6V4NgkMjgxnogUDJe1rAUx
# artist id:  0GvoilgXudnVgLkkxYCttN
# genres = []
# Processing track #152
# artist id:  4OZ0VK1N3PDtGhY2d6sqhI
# Processing track #153
# artist id:  1GLnhRhNDXOofP7IlDxT5q
# genres = []
# Processing track #154
# artist id:  3VwKSHAfgzV1DOHV0aANCI
# Processing track #155
# artist id:  32ogthv0BdaSMPml02X9YB
# Processing track #156
# artist id:  2KRjFUNJ9GJepRGAGextuq
# genres = []
# Processing track #157
# artist id:  2dUsAHSrnsFvNpNpAV4aGI
# Processing track #158
# artist id:  3JKd43oYlE7ifoodXetsuw
# Processing track #159
# artist id:  4RSNNGdvEfBA2s3ziDFUlU
# genres = []
# Processing track #160
# artist id:  08Xoy5Glpl7MyzzZsRfRPJ
# Processing track #161
# artist id:  7eEhAAe2A5cCZSd3d8XLmY
# Processing track #162
# artist id:  3TATyyszdAMkqwHxhB7uEP
# genres = []
# Processing track #163
# artist id:  1C2rCgyUlqHUx1Xm0KXUik
# Processing track #164
# artist id:  6RnzEFYNyKinHv6r86yeBI
# genres = []
# Processing track #165
# artist id:  6d35bYlz60TdmYGMkBhIiJ
# Processing track #166
# artist id:  6d35bYlz60TdmYGMkBhIiJ
# Processing track #167
# artist id:  468ohR5I3vI6JztrHL7exy
# Processing track #168
# artist id:  38jDRxwK5wuTKAk54LEj1F
# Processing track #169
# artist id:  2sXAc7uyVF7HwCwPa1ATuT
# genres = []
# artist id:  37j8MfvLiRbow3d4kXxiv7
# genres = []
# Processing track #170
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #171
# artist id:  4huXijLHlm8VMzeob86QvD
# Processing track #172
# artist id:  399t4qwl1M9sMlOtlxVP7e
# Processing track #173
# artist id:  3rQwLE64J8IhEMWnZm8ZmH
# Processing track #174
# artist id:  0mNH2qJuYWxGtpgPJYPIY2
# genres = []
# Processing track #175
# artist id:  607NT5Fu5CwN4tBPKD7HoE
# genres = []
# Processing track #176
# artist id:  4Rcol4u0q89lypqKI83GDz
# Processing track #177
# artist id:  4dktzc5hWsQPqmovObGZIG
# Processing track #178
# artist id:  5ciaSthWeAWrVQ4eUJMrpy
# genres = []
# Processing track #179
# artist id:  4YIfxtjEDbtQpVmspJZTLd
# Processing track #180
# artist id:  3OsRAKCvk37zwYcnzRf5XF
# Processing track #181
# artist id:  3X1fGv94hiyQQ8Sc7GRE0K
# Processing track #182
# artist id:  468ohR5I3vI6JztrHL7exy
# Processing track #183
# artist id:  6WHCgS2g18qWw45K66DdRZ
# Processing track #184
# artist id:  3PcDrMW2mUYxuKB5Ue3c86
# genres = []
# artist id:  7bCMn3cDvGs8Ua8f2JICZa
# genres = []
# Processing track #185
# artist id:  7JxiGkTUF8p8R1Ki5CNJNH
# genres = []
# Processing track #186
# artist id:  3OtCzBJs5hFZapz4lY6aWa
# genres = []
# Processing track #187
# artist id:  5eJVBynWXdVYZfxeER5gqQ
# genres = []
# Processing track #188
# artist id:  6sCCuLIretI6tjWI8bLOME
# genres = []
# Processing track #189
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #190
# artist id:  0Upbj4hHk4d4UJ0HhnVs4F
# Processing track #191
# artist id:  179BpmLkQCRIoU68Co80f5
# Processing track #192
# artist id:  0hc2qwaU2xy7LUd0FRjcHK
# Processing track #193
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #194
# artist id:  4w8MWlPCLi8uZRkCMyrtCO
# Processing track #195
# artist id:  0mNH2qJuYWxGtpgPJYPIY2
# genres = []
# Processing track #196
# artist id:  2dI9IuajQnLR5dLxHjTTqU
# artist id:  5RyaBwFlrXhvhDGZNSb8Vw
# genres = []
# Processing track #197
# artist id:  2jvKLLBED6JvKWtT8y3kCu
# Processing track #198
# artist id:  5LrXI2SwrD9P30B6CqOjNV
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #199
# artist id:  3cbU0WxlZJTFLTfXEUB433
# Processing track #200
# artist id:  5EEbMGQOwrTuy51Vin8bL1
# Processing track #201
# artist id:  4awnjjqiUnSBA4ucPVbF8R
# Processing track #202
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #203
# artist id:  2E2bPcE2HtOgwvNbHu7mOk
# Processing track #204
# artist id:  4awnjjqiUnSBA4ucPVbF8R
# Processing track #205
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# artist id:  06tYi7DxoKe8PfYCeHGGFK
# genres = []
# Processing track #206
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #207
# artist id:  4Rj2COYs5hQsw8rYIxSviz
# Processing track #208
# artist id:  0hc2qwaU2xy7LUd0FRjcHK
# Processing track #209
# artist id:  09JW90QIws2Z3H8hxL5fFN
# Processing track #210
# artist id:  4yaAWRaVs0TWFiFMUBNAvA
# genres = []
# Processing track #211
# artist id:  0mNH2qJuYWxGtpgPJYPIY2
# genres = []
# Processing track #212
# artist id:  5ciaSthWeAWrVQ4eUJMrpy
# genres = []
# Processing track #213
# artist id:  3Muhm9HEowEpdC0i6NuW3P
# Processing track #214
# artist id:  6M8inuI8fuWKvTgIdUmOuA
# Processing track #215
# artist id:  6M8inuI8fuWKvTgIdUmOuA
# Processing track #216
# artist id:  6M8inuI8fuWKvTgIdUmOuA
# Processing track #217
# artist id:  4BszhWpm1hnrTV8E8YONts
# genres = []
# Processing track #218
# artist id:  5I7n9qoy56ibexYfrF9ZEL
# Processing track #219
# artist id:  5ciaSthWeAWrVQ4eUJMrpy
# genres = []
# Processing track #220
# artist id:  3cbU0WxlZJTFLTfXEUB433
# Processing track #221
# artist id:  6yGW6Z2OraCYUr9OsqZo2x
# Processing track #222
# artist id:  3BvEQzdNFTD0hoeZCAt3WZ
# artist id:  2TWKl87Jnmd5MApKEpVCxA
# Processing track #223
# artist id:  2dI9IuajQnLR5dLxHjTTqU
# artist id:  5KMHsLGu81oGxb6tDlY2qc
# genres = []
# artist id:  1KptbKul07HfHKjszGncbQ
# genres = []
# Processing track #224
# artist id:  09JW90QIws2Z3H8hxL5fFN
# Processing track #225
# artist id:  33WEbJHirq23bohapH3pI9
# Processing track #226
# artist id:  09JW90QIws2Z3H8hxL5fFN
# Processing track #227
# artist id:  0dU2EKM6vca3xmJ9kl8zoI
# Processing track #228
# artist id:  5PFVryAyJqvirWkPBkwagn
# genres = []
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #229
# artist id:  09JW90QIws2Z3H8hxL5fFN
# Processing track #230
# artist id:  4dktzc5hWsQPqmovObGZIG
# Processing track #231
# artist id:  00G1NTDAoU7rBpjG4KoYAM
# Processing track #232
# artist id:  5EEbMGQOwrTuy51Vin8bL1
# Processing track #233
# artist id:  09JW90QIws2Z3H8hxL5fFN
# Processing track #234
# artist id:  6iqEys0P20ku952osCLqD1
# genres = []
# Processing track #235
# artist id:  0dU2EKM6vca3xmJ9kl8zoI
# Processing track #236
# artist id:  4veIvBHKoUacjuoMOm3vsg
# Processing track #237
# artist id:  3Hue0QXHSHhpjbqWk3HmtY
# artist id:  29osCpAsrEiHxE8t6khiJr
# Processing track #238
# artist id:  0dU2EKM6vca3xmJ9kl8zoI
# Processing track #239
# artist id:  6Iuyxid73G505WDnHEBPup
# genres = []
# Processing track #240
# artist id:  2E2bPcE2HtOgwvNbHu7mOk
# Processing track #241
# artist id:  2AY0TMFBRlygIiGsk2kiOP
# artist id:  14EybDMySlkntyuxgm1pek
# Processing track #242
# artist id:  3Gaqw2nGyE7yM3rcRSzE3U
# Processing track #243
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #244
# artist id:  4BszhWpm1hnrTV8E8YONts
# genres = []
# Processing track #245
# artist id:  5PFVryAyJqvirWkPBkwagn
# genres = []
# Processing track #246
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #247
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #248
# artist id:  5PFVryAyJqvirWkPBkwagn
# genres = []
# artist id:  2N5BJEXSPup1i4j2xiGZFP
# Processing track #249
# artist id:  4dktzc5hWsQPqmovObGZIG
# Processing track #250
# artist id:  6mMCSCuTbGU6kNr4303LwH
# Processing track #251
# artist id:  5DZr9dQj9KPd62WuMeIPqK
# Processing track #252
# artist id:  4VNKVCluxMcjqwYJm3yuQ3
# Processing track #253
# artist id:  5Wh6rX9iEMrUSLDlLGztPS
# Processing track #254
# artist id:  4TIrC99WSg0tOtBCGDjMRY
# Processing track #255
# artist id:  0CLRpcHXiZS33XwebzMZ6B
# Processing track #256
# artist id:  6M8inuI8fuWKvTgIdUmOuA
# Processing track #257
# artist id:  6M8inuI8fuWKvTgIdUmOuA
# Processing track #258
# artist id:  57BliIwnAIqKeI4dbAWwaU
# Processing track #259
# artist id:  4Rj2COYs5hQsw8rYIxSviz
# Processing track #260
# artist id:  6M8inuI8fuWKvTgIdUmOuA
# Processing track #261
# artist id:  0YM0WizsRh0lblEA9fdDRX
# genres = []
# Processing track #262
# artist id:  0IE9bo85AcWOSL9Y5UINsM
# genres = []
# artist id:  4yaAWRaVs0TWFiFMUBNAvA
# genres = []
# Processing track #263
# artist id:  6M8inuI8fuWKvTgIdUmOuA
# Processing track #264
# artist id:  6M8inuI8fuWKvTgIdUmOuA
# Processing track #265
# artist id:  0WeWsgv7wWrgSHKBCInMv0
# artist id:  31zy0wXEDg4NGlOGCCwz92
# genres = []
# Could not find related genres for artist: 31zy0wXEDg4NGlOGCCwz92
# Processing track #266
# artist id:  6pqiqWEK6A4VDYVJdNVZaz
# genres = []
# artist id:  4MtoPS2GV2hUxacTHz9J6p
# genres = []
# Could not find related genres for artist: 4MtoPS2GV2hUxacTHz9J6p
# Processing track #267
# artist id:  6k0DgDKA5WW1H4iJhXV2Ae
# Processing track #268
# artist id:  6u4jLGLPuarS3i2XWHVxoS
# Processing track #269
# artist id:  6ITKskiAcS4w9egVKClT7e
# Processing track #270
# artist id:  523y9KSneKh6APd1hKxLuF
# artist id:  4cfKtwkefMW3aiXtxfw8w6
# Processing track #271
# artist id:  7pHwBqsYULdAdHgSwf1q9f
# artist id:  1Xb1BccDF2oroI5r8MT5ne
# genres = []
# Processing track #272
# artist id:  3vDh2Mern1I2k53Oy0pDlD
# artist id:  2ykUp1K8tRaOUFd8vvcwXl
# Processing track #273
# artist id:  2Zvo5BEkHyaHD1zk180kMz
# Processing track #274
# artist id:  0ZGZmWtWphCJmiN1ENgSc5
# Processing track #275
# artist id:  7ms0f0617Pbchfrv3sEdaE
# Processing track #276
# artist id:  6EVgiuWVrdencro4gjLJKE
# genres = []
# Processing track #277
# artist id:  6af8aRyYJXqbM7u9qljiRk
# artist id:  4gJMOPjz1OUnD6TysFPUr1
# artist id:  2dI9IuajQnLR5dLxHjTTqU
# artist id:  5KMHsLGu81oGxb6tDlY2qc
# genres = []
# Processing track #278
# artist id:  33W9Pu3NHtSlqbaOI6pqXn
# artist id:  5YIxufplJpHkE3S1MXQr63
# artist id:  6AMQy6wV8kkEPOociPAmYp
# genres = []
# Could not find related genres for artist: 6AMQy6wV8kkEPOociPAmYp
# Processing track #279
# artist id:  1RvsCdAQoizcHBGTyYjkQA
# Processing track #280
# artist id:  3TXlzdvGPfqcdclaUSFBDd
# artist id:  4nyHE938llzw3YCfqXzf6B
# genres = []
# Could not find related genres for artist: 4nyHE938llzw3YCfqXzf6B
# artist id:  4WHppDti0CTvvdGmkQjZOc
# genres = []
# Could not find related genres for artist: 4WHppDti0CTvvdGmkQjZOc
# artist id:  2SGYN2YJ3kyEW2SDl5vcdn
# genres = []
# Processing track #281
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  0vNpT8ZtiGQVhi0AvDWpsG
# artist id:  0bqNGlh4NGgVj8NHjP10Jm
# genres = []
# Could not find related genres for artist: 0bqNGlh4NGgVj8NHjP10Jm
# artist id:  2SGYN2YJ3kyEW2SDl5vcdn
# genres = []
# Processing track #282
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  1c1hWS9bv16AlxgpPkBsFD
# genres = []
# Processing track #283
# artist id:  5KMHsLGu81oGxb6tDlY2qc
# genres = []
# artist id:  3Hg0Oo6hrlDBYcWqQtTTNr
# genres = []
# Processing track #284
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  5yUtOYdnxxWdcIoZM1dx68
# artist id:  2SGYN2YJ3kyEW2SDl5vcdn
# genres = []
# Processing track #285
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  5yUtOYdnxxWdcIoZM1dx68
# artist id:  2XvQyfssNbXYWcOkKaWYlx
# Processing track #286
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  10GhCaNUj3J513uGlNuya6
# genres = []
# Could not find related genres for artist: 10GhCaNUj3J513uGlNuya6
# artist id:  2xyVFtpCBUMlbAcCqRg1jv
# genres = []
# Could not find related genres for artist: 2xyVFtpCBUMlbAcCqRg1jv
# artist id:  6gwlTwJNBRJ8l8phOAQCEI
# Processing track #287
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  3Hg0Oo6hrlDBYcWqQtTTNr
# genres = []
# Processing track #288
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  5KMHsLGu81oGxb6tDlY2qc
# genres = []
# Processing track #289
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  1UgScm0DiP6KrWyNDw0lS4
# genres = []
# Processing track #290
# artist id:  5KMHsLGu81oGxb6tDlY2qc
# genres = []
# artist id:  3Hg0Oo6hrlDBYcWqQtTTNr
# genres = []
# Processing track #291
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  6gwlTwJNBRJ8l8phOAQCEI
# Processing track #292
# artist id:  64FRiqIrUyWPvGb83fAYLn
# Processing track #293
# artist id:  2TQThrKSXqIsCGGbyN5ARi
# genres = []
# Processing track #294
# artist id:  0R7kz98b2zjiuU3AffoeYz
# Processing track #295
# artist id:  1WjBIvYAnZTkTh5UiZNwlR
# Processing track #296
# artist id:  0MqfYdygGLnHjhmXc9yDeH
# artist id:  2I5mHt4jJQJjnzS9NuDr6J
# genres = []
# Processing track #297
# artist id:  33AlE9XaZmnAtfWFhjNL5e
# artist id:  7nP2FHl2iiLMoisGGK1rHb
# genres = []
# artist id:  2jThzVlmtCAmixeDu0xy6w
# genres = []
# Could not find related genres for artist: 2jThzVlmtCAmixeDu0xy6w
# Processing track #298
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# artist id:  2N5BJEXSPup1i4j2xiGZFP
# Processing track #299
# artist id:  5aPyGWlpqRG3hlsbTDgPPu
# genres = []
# Processing track #300
# artist id:  1LNciO7hxkWoSQ3V8OWNQF
# Processing track #301
# artist id:  3GEUIa3Z0Qlivy3EcJm5RX
# Processing track #302
# artist id:  3UlxLrm4Nt8Ga2eLv4RoN2
# genres = []
# Processing track #303
# artist id:  4U4uJqITRN0eWFfDg5yG8C
# genres = []
# Processing track #304
# artist id:  1Gqv9YkzHHS3jyQb0DvQTv
# Processing track #305
# artist id:  7IZWH07w9P4HXc2Qo9xwpY
# Processing track #306
# artist id:  43KGNBtCYujVFg0pbqJiaA
# artist id:  4lQbdxWVeDoHJIiyL05i44
# genres = []
# Processing track #307
# artist id:  4pa9r05W0vQ8lQ52ZCJDy2
# Processing track #308
# artist id:  6UyjYM7EYNjB07N1TIyZZn
# Processing track #309
# artist id:  4bODnAlydTbem2JAjDX52y
# Processing track #310
# artist id:  10oQYnkq1OabU5HHburShK
# genres = []
# Processing track #311
# artist id:  0xD1RASjJGXnTh5NxdrKxF
# Processing track #312
# artist id:  6VxCmtR7S3yz4vnzsJqhSV
# Processing track #313
# artist id:  4mxvEx9dRyDe0xOlwhtoXd
# artist id:  1VF2jmv5aWGszBtIVPt2fT
# Processing track #314
# artist id:  1f8646DgHta6Gl3eLxZTdk
# Processing track #315
# artist id:  7hyKm6cdFkaqtPCN3afkTJ
# genres = []
# Processing track #316
# artist id:  32ogthv0BdaSMPml02X9YB
# artist id:  3fYr24qYhJejxewFrckFE4
# Processing track #317
# artist id:  6oUtPvVnMi9RTC6Jw0r10B
# genres = []
# Could not find related genres for artist: 6oUtPvVnMi9RTC6Jw0r10B
# artist id:  2r0ObJXTskHprYdL1iXUMo
# genres = []
# Processing track #318
# artist id:  5WCWKVOVoAEY3l3AHAiDql
# Processing track #319
# artist id:  65EXuYHVoehCKqp0kOS6px
# artist id:  0BGNyKGO4LaL69kurXlaSI
# Processing track #320
# artist id:  6NXUwvUyluZOSTcYj8qe8F
# Processing track #321
# artist id:  4OvLy4oD9IFQ8YCbbMDVRD
# Processing track #322
# artist id:  4Mlxc3DHm3Qr5XTaEXHT6f
# Processing track #323
# artist id:  3Hue0QXHSHhpjbqWk3HmtY
# artist id:  6h7ndBCXhabUn9QnqG3q1B
# genres = []
# Processing track #324
# artist id:  0142LFmMLrdw3PWx8yCo3X
# artist id:  5sAYEIJqK8n8Fvv0JhdomS
# genres = []
# Could not find related genres for artist: 5sAYEIJqK8n8Fvv0JhdomS
# Processing track #325
# artist id:  7ItbAZITSFxSy5LJChXe18
# artist id:  1ONhS8pN5UbzqoZlLF69kI
# Processing track #326
# artist id:  3zSb5nFV4XJiPlawyyo8xn
# genres = []
# artist id:  3LijUg92GG1XomQ1OkuvfD
# genres = []
# Processing track #327
# artist id:  1Q2ifiLn6HWlRAlycDOsvk
# Processing track #328
# artist id:  1Zt82Ejt6v5R7zzySu8A1n
# genres = []
# Processing track #329
# artist id:  2Zvo5BEkHyaHD1zk180kMz
# artist id:  1uL5R0NdFIaacJE1W8p7Bi
# genres = []
# artist id:  3TOcsmPjuFCARycuQEGepB
# genres = []
# Could not find related genres for artist: 3TOcsmPjuFCARycuQEGepB
# Processing track #330
# artist id:  5FjTtbpfWj8SBN3SGjkY0W
# artist id:  5bAM9ltcPO19tC7yCLH4vr
# Processing track #331
# artist id:  1E9ev9hZVmtmeFkS3ZAyyw
# artist id:  7EHVLFAxz7VPpkyUqEt4y1
# genres = []
# Processing track #332
# artist id:  3HV5zAEqTKXHhbF9PsN6Uo
# artist id:  7q9AmXPI7sYCKR75Fpdi45
# genres = []
# Processing track #333
# artist id:  44HQ4cmv8MKMNHkPtXwZbQ
# Processing track #334
# artist id:  3boYI1yAlZAm5NmtCitCFj
# Processing track #335
# artist id:  5tDjiBYUsTqzd0RkTZxK7u
# genres = []
# Processing track #336
# artist id:  4QEVURpkcQMAKrF5bTHPcN
# genres = []
# artist id:  4htjQW3lgIwL6fEJlTOez4
# artist id:  3en0QcDtCiuzfLCD02dgyo
# genres = []
# Could not find related genres for artist: 3en0QcDtCiuzfLCD02dgyo
# Processing track #337
# artist id:  7lHiOFpepHokhLTy6PNAL9
# Processing track #338
# artist id:  29osCpAsrEiHxE8t6khiJr
# artist id:  74g6eILGPWrSGTQqQp5dlp
# Processing track #339
# artist id:  7MIDaIHvsSEayCv0pw3okp
# genres = []
# artist id:  0LC3HTEh3afI3UfpmSdShk
# genres = []
# Processing track #340
# artist id:  29osCpAsrEiHxE8t6khiJr
# Processing track #341
# artist id:  1jG7yqKlaLOoTEhheRCvHy
# Processing track #342
# artist id:  79OTUKSZMGMmmR32RWG2ig
# artist id:  6h4za7JJtfn8inpnRsB8Cb
# genres = []
# Processing track #343
# artist id:  0uLnAkNKYtVbCJSviFZnEh
# genres = []
# Processing track #344
# artist id:  7wCWfhgnNqwe78oCh3n02p
# genres = []
# Processing track #345
# artist id:  1BdgyHJZID1ceLLg31KyAv
# Processing track #346
# artist id:  6Tcndnzi3lQNgUmoVXmtb4
# Processing track #347
# artist id:  1RvsCdAQoizcHBGTyYjkQA
# artist id:  6FxwDk5PwM0I9w67rRy86z
# genres = []
# Could not find related genres for artist: 6FxwDk5PwM0I9w67rRy86z
# artist id:  7xvqBkPXXzfkSC7r1rMk1P
# genres = []
# Could not find related genres for artist: 7xvqBkPXXzfkSC7r1rMk1P
# Processing track #348
# artist id:  5HNAKwy6K9OwZO1zkO6vax
# Processing track #349
# artist id:  6gK1Uct5FEdaUWRWpU4Cl2
# Processing track #350
# artist id:  5Ld19xtpAR80G2boTcHaVx
# Processing track #351
# artist id:  29osCpAsrEiHxE8t6khiJr
# artist id:  2biUg7GntNwKlyyWTZ28rL
# genres = []
# Processing track #352
# artist id:  2RgG6fm1Vqpm3y7XMzGSyt
# genres = []
# Processing track #353
# artist id:  52Jpr73eTCxjWBzhLyg1qk
# genres = []
# Could not find related genres for artist: 52Jpr73eTCxjWBzhLyg1qk
# artist id:  0okmfBroVgFuvvljnUbqPW
# Processing track #354
# artist id:  2XvQyfssNbXYWcOkKaWYlx
# artist id:  3Hg0Oo6hrlDBYcWqQtTTNr
# genres = []
# artist id:  3ohmouyL3xWW70OiC5ATDI
# artist id:  2SGYN2YJ3kyEW2SDl5vcdn
# genres = []
# Processing track #355
# artist id:  3HH77UShAG2WJW5nBSjFdY
# Processing track #356
# artist id:  16VwyZdaNKjbvBUoTKCdUu
# Processing track #357
# artist id:  64MJxMlRak8Xgh3N9vePD1
# genres = []
# Could not find related genres for artist: 64MJxMlRak8Xgh3N9vePD1
# Could not find related genres for the track: 'Mobiagse - Mixed' (id: '4NHeCNltciImyZexSMNRwc')
# Processing track #358
# artist id:  5nNJbOr2phyzj0KvIv7HL1
# Processing track #359
# artist id:  4VbWKy3JWAFBro0dARznBa
# artist id:  6FoBXLAwetXmN0Ez7Qxjug
# genres = []
# Processing track #360
# artist id:  3IcRL0XU2Qhyyblh10vIMi
# Processing track #361
# artist id:  2XvQyfssNbXYWcOkKaWYlx
# Processing track #362
# artist id:  3yjJoAP3B8paC6tedRJ7ii
# Processing track #363
# artist id:  29osCpAsrEiHxE8t6khiJr
# artist id:  0dChoTLv7Af0baOzH5UZlt
# genres = []
# Processing track #364
# artist id:  7gO5Zxv0gQXMTkus0ro8tj
# Processing track #365
# artist id:  3boYI1yAlZAm5NmtCitCFj
# Processing track #366
# artist id:  1KQ1687z0hWSabx0YswG54
# Processing track #367
# artist id:  6N2bCZFo999TqhtdPTnLyq
# artist id:  2W3M7XIkEKENCT1LXJ6mdj
# artist id:  3eeLa5OM4VTkCi6XK84yDE
# genres = []
# Processing track #368
# artist id:  4DTUmkn8z1XIzHPr5b0yEc
# Processing track #369
# artist id:  0fs9otT9TtwXUOcFXZomZY
# artist id:  38qnDEjuo43UZMmxZRcK6G
# genres = []
# Could not find related genres for artist: 38qnDEjuo43UZMmxZRcK6G
# Processing track #370
# artist id:  2GL5OJQQ0qp2rtth8iy6Kf
# genres = []
# Processing track #371
# artist id:  3AV95VmpdGWvNzoHURs9KQ
# artist id:  10kvtUeNFgcDQZDtiAC8s4
# genres = []
# Could not find related genres for artist: 10kvtUeNFgcDQZDtiAC8s4
# Processing track #372
# artist id:  2wo3eLY26t8AMyYuYi1pZQ
# Processing track #373
# artist id:  4pAYkltTzVhqBZuDekCHa3
# Processing track #374
# artist id:  7MSUfLeTdDEoZiJPDSBXgi
# Processing track #375
# artist id:  5evuJYN1sgxxSQWs9mw1e3
# Processing track #376
# artist id:  21tDFddcOFDYmiobTcls2O
# Processing track #377
# artist id:  7xL1MTYNKgYaNjnL9ey73A
# Processing track #378
# artist id:  5DZr9dQj9KPd62WuMeIPqK
# Processing track #379
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #380
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #381
# artist id:  0sjhSgEkyVa8QRmkkuckJ0
# Processing track #382
# artist id:  4kg2lRWVK6LDOwPfhQrhsn
# Processing track #383
# artist id:  4aYY1AgpWSwvN8Su8GGExO
# genres = []
# Processing track #384
# artist id:  7nFb95Ufz3MkdXP4bnlSES
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #385
# artist id:  0fvpn2k7FymYHxEx5U5FpP
# Processing track #386
# artist id:  0LMkPoi2xIgpOPUSJMftqM
# Processing track #387
# artist id:  7jAeRfT8LYCxydM2Y1Egvn
# artist id:  2IxTI7YzL1d2MhS6O1CJMj
# genres = []
# Processing track #388
# artist id:  7nFb95Ufz3MkdXP4bnlSES
# Processing track #389
# artist id:  4pgjEpAP1k4epnwZWmbHTf
# Processing track #390
# artist id:  7nFb95Ufz3MkdXP4bnlSES
# Processing track #391
# artist id:  7HvQfRNJCvPXTVirKKB0Nn
# Processing track #392
# artist id:  6HCnsY0Rxi3cg53xreoAIm
# Processing track #393
# artist id:  00G1NTDAoU7rBpjG4KoYAM
# Processing track #394
# artist id:  1hEsWULPTu0YtBuQyFQTL7
# Processing track #395
# artist id:  4pgjEpAP1k4epnwZWmbHTf
# Processing track #396
# artist id:  38CPjAAqYV8lTYi6clzbjG
# artist id:  1Gy2CxCb9Bvp6Wp0xQmSbq
# genres = []
# artist id:  08MG1w8piIBNcK7H4TTazQ
# genres = []
# Could not find related genres for artist: 08MG1w8piIBNcK7H4TTazQ
# artist id:  50appzhosvzQcqmeipXLtP
# genres = []
# Could not find related genres for artist: 50appzhosvzQcqmeipXLtP
# artist id:  7ynQZmXaxvWuYmrHkVxs9u
# genres = []
# Could not find related genres for artist: 7ynQZmXaxvWuYmrHkVxs9u
# Processing track #397
# artist id:  484sZUYmnRXN84zmk3GY1n
# artist id:  5E1HWPplEsztsh2zh1c9mH
# Processing track #398
# artist id:  484sZUYmnRXN84zmk3GY1n
# Processing track #399
# artist id:  484sZUYmnRXN84zmk3GY1n
# Processing track #400
# artist id:  484sZUYmnRXN84zmk3GY1n
# Processing track #401
# artist id:  484sZUYmnRXN84zmk3GY1n
# Processing track #402
# artist id:  238y1dKPtMeFEpX3Y6H1Vr
# Processing track #403
# artist id:  1VJspRsoC6c0bvqhnSiFCs
# Processing track #404
# artist id:  2OpHxx1SArSMlBrIMM0aV9
# Processing track #405
# artist id:  5WcGRaGsl0b9sul7jVdDgc
# Processing track #406
# artist id:  4pVLzmuKU51CVcXRNpDuJ6
# Processing track #407
# artist id:  0xYZnLkJHs6y9Ts7Yq2C1C
# artist id:  70vJ4IvBtlCutfLNkxqoSu
# Processing track #408
# artist id:  3yu4VilcxpQ6h35vRcemBp
# Processing track #409
# artist id:  1CEqyczKKYNhzgqCjH7G7Q
# artist id:  1ppFAqWZIgv5c7huT7O3Aa
# genres = []
# Processing track #410
# artist id:  2CiO7xWdwPMDlVwlt9qa1f
# genres = []
# Processing track #411
# artist id:  2mKQjbuUTbiWeg2PaHrq65
# Processing track #412
# artist id:  0eHY5jLP9TgzxYhT19Sqyq
# Processing track #413
# artist id:  2jXlqT8v9XIJnKQYRgLvSr
# Processing track #414
# artist id:  0upXUo04k4k8bGVSkmgrSc
# Processing track #415
# artist id:  6CFWXwqEBUi0UFoIIxmg9h
# Processing track #416
# artist id:  1h4iSQAKdvAAm07l6FX6dy
# Processing track #417
# artist id:  0I6bdBR4Q7uoc3HI1OgI8C
# Processing track #418
# artist id:  2YPwmHkQNmY3YNcTuG7CGw
# Processing track #419
# artist id:  0nGxKkhmIzyu6bvuXrko1e
# Processing track #420
# artist id:  7pQsw5jT4ZGfjo47JFQTXN
# genres = []
# Processing track #421
# artist id:  5iVuj2TcNIEBNnzGk97vfT
# Processing track #422
# artist id:  3HRRzIZNQFus3xlUx2xKy1
# Processing track #423
# artist id:  5If5Tdg66Q5X3L57G7A6Pn
# Processing track #424
# artist id:  5If5Tdg66Q5X3L57G7A6Pn
# Processing track #425
# artist id:  7G1GBhoKtEPnP86X2PvEYO
# artist id:  2ZX9eBv3ycTNpZrWMRtWte
# Processing track #426
# artist id:  7su1fG75ZwXHA6ei9Zcy7T
# Processing track #427
# artist id:  6X8lhZ7YaRUBlOsOYimlyD
# Processing track #428
# artist id:  51qSeH9HimuYMMQ7qbWGrk
# Processing track #429
# artist id:  0RKP3F2s1SHvGpckHuW4S7
# genres = []
# Could not find related genres for artist: 0RKP3F2s1SHvGpckHuW4S7
# artist id:  5tY2sa8I11tpMuhU9onQ6e
# Processing track #430
# artist id:  53PSeUFq8tMZc0zdd1oUTG
# genres = []
# artist id:  2ErWVVcMH1io3Au40dTKnG
# artist id:  09jtkgopdNOFuQKcOPPdeP
# genres = []
# Could not find related genres for artist: 09jtkgopdNOFuQKcOPPdeP
# Processing track #431
# artist id:  0CdxxbmCwuQ0dV9LvvyqlO
# Processing track #432
# artist id:  7lHiOFpepHokhLTy6PNAL9
# Processing track #433
# artist id:  7G1GBhoKtEPnP86X2PvEYO
# artist id:  6E7SbenCPEit9gDFnMlDUA
# genres = []
# Processing track #434
# artist id:  3kI19T2Y7mzINNIOGHTg5P
# Processing track #435
# artist id:  4qyyx2In3fnMlPjQBfppNn
# Processing track #436
# artist id:  3eMm5tVcg2mskULezmBKQA
# artist id:  11nPnjisPOKrgXPxTlNoY2
# genres = []
# Processing track #437
# artist id:  1VVYETYOF4Iw0KtrBIrllj
# artist id:  0QLpgAwusvxcZD7OB0HsHX
# genres = []
# Could not find related genres for artist: 0QLpgAwusvxcZD7OB0HsHX
# Processing track #438
# artist id:  0OO1zgX3CUfJQwoOEBSKSp
# Processing track #439
# artist id:  0CKCPpRz1XftUQN3ipEkbe
# Processing track #440
# artist id:  0IhfJZiFjHqE9mJ9INjp7x
# Processing track #441
# artist id:  3OAGf3vGsxLFCDs5QYXOsk
# genres = []
# Processing track #442
# artist id:  0FtVISUJUZSWPU4LGeovTM
# Processing track #443
# artist id:  6d6i5VzXGwecR7EtMasWsZ
# Processing track #444
# artist id:  1dZtTzcPTFBsbmqNohoKUR
# artist id:  2oQJQUIpJFFnfKvHJA0xBu
# Processing track #445
# artist id:  2StcyX3fmelae5agBHIkDO
# Processing track #446
# artist id:  6d6i5VzXGwecR7EtMasWsZ
# Processing track #447
# artist id:  4zygNhOWWhflJVjoHMul6K
# Processing track #448
# artist id:  4i0bLWWYQMI3P1KFrTWsHG
# Processing track #449
# artist id:  4MismZLKqMb2Qb2HjK4sdE
# Processing track #450
# artist id:  4MismZLKqMb2Qb2HjK4sdE
# Processing track #451
# artist id:  7G1GBhoKtEPnP86X2PvEYO
# artist id:  1ArnxWTsCwu45hZY7w3sPX
# genres = []
# Could not find related genres for artist: 1ArnxWTsCwu45hZY7w3sPX
# Processing track #452
# artist id:  3CdsJ9u53uPu3dScKypLVv
# artist id:  3kcNoqtw8cpeiZ5AjrSCZj
# genres = []
# Could not find related genres for artist: 3kcNoqtw8cpeiZ5AjrSCZj
# Processing track #453
# artist id:  0NzZrLash5LUV2gSr0jUXE
# Processing track #454
# artist id:  5If5Tdg66Q5X3L57G7A6Pn
# Processing track #455
# artist id:  65c5si0ePAwkOCn4M35Ho7
# Processing track #456
# artist id:  4KbAqExGPdHdVchyF8BBAR
# Processing track #457
# artist id:  2P98rkELDQVyC1olsD2Cej
# Processing track #458
# artist id:  49z6oAiD2RpyUf5yLJs7Nf
# Processing track #459
# artist id:  49z6oAiD2RpyUf5yLJs7Nf
# Processing track #460
# artist id:  3T2iIPbvIyKJdXNrFYiYXn
# Processing track #461
# artist id:  4EBRPnSYtrfmwptEMOSCV8
# Processing track #462
# artist id:  0Nks3cFWU2a7rooAlFQYgn
# artist id:  4EBRPnSYtrfmwptEMOSCV8
# Processing track #463
# artist id:  4EBRPnSYtrfmwptEMOSCV8
# Processing track #464
# artist id:  4EBRPnSYtrfmwptEMOSCV8
# Processing track #465
# artist id:  4PmxbsWP1u0TnvqcrIA9ze
# Processing track #466
# artist id:  4PmxbsWP1u0TnvqcrIA9ze
# Processing track #467
# artist id:  4PmxbsWP1u0TnvqcrIA9ze
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# Processing track #468
# artist id:  4PmxbsWP1u0TnvqcrIA9ze
# Processing track #469
# artist id:  4PmxbsWP1u0TnvqcrIA9ze
# Processing track #470
# artist id:  6sz0k1q2aEtG5dxEgr4YWV
# Processing track #471
# artist id:  6sz0k1q2aEtG5dxEgr4YWV
# Processing track #472
# artist id:  6sz0k1q2aEtG5dxEgr4YWV
# Processing track #473
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #474
# artist id:  2nCACYdIndYchzX4bxLcTW
# artist id:  0ShXtJGjzmboEPVOvIdbQA
# Processing track #475
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #476
# artist id:  5s9GgX51pD0YhcsQRSYlpF
# artist id:  2nCACYdIndYchzX4bxLcTW
# artist id:  3jp9DGR5F8TTMJJL7szQFI
# genres = []
# Processing track #477
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #478
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #479
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #480
# artist id:  2nCACYdIndYchzX4bxLcTW
# artist id:  0OQeMFqoRD5clB0cPYVbxY
# Processing track #481
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #482
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #483
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #484
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #485
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #486
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #487
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #488
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #489
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #490
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #491
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #492
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #493
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #494
# artist id:  63Bilw49Uv4s2wnovytDVU
# Processing track #495
# artist id:  6CFWXwqEBUi0UFoIIxmg9h
# Processing track #496
# artist id:  6CFWXwqEBUi0UFoIIxmg9h
# artist id:  65CKKZilbcSKkAPC9a5Mvh
# Processing track #497
# artist id:  6CFWXwqEBUi0UFoIIxmg9h
# artist id:  4ZdJ35EaWtMCvdbczspFET
# genres = []
# artist id:  4Lu4jDj4ky1wxvRDgL90tc
# genres = []
# Processing track #498
# artist id:  6CFWXwqEBUi0UFoIIxmg9h
# Processing track #499
# artist id:  6CFWXwqEBUi0UFoIIxmg9h
# Processing track #500
# artist id:  6CFWXwqEBUi0UFoIIxmg9h
# Processing track #501
# artist id:  6CFWXwqEBUi0UFoIIxmg9h
# Processing track #502
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #503
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #504
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# Processing track #505
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #506
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #507
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  2nCACYdIndYchzX4bxLcTW
# Processing track #508
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  1CPwHx5lgVxv0rfcp7UXLx
# Processing track #509
# artist id:  3mNygoyrEKLgo6sx0MzwOL
# artist id:  1CPwHx5lgVxv0rfcp7UXLx
# Processing track #510
# artist id:  7xT0arvCDupDU1YYy0BNv9
# Processing track #511
# artist id:  7xT0arvCDupDU1YYy0BNv9
# Processing track #512
# artist id:  7xT0arvCDupDU1YYy0BNv9
# Processing track #513
# artist id:  7xT0arvCDupDU1YYy0BNv9
# Processing track #514
# artist id:  7xT0arvCDupDU1YYy0BNv9
# artist id:  396biTOuSgatR6cQxDFL2T
# genres = []
# Could not find related genres for artist: 396biTOuSgatR6cQxDFL2T
# Processing track #515
# artist id:  7xT0arvCDupDU1YYy0BNv9
# Processing track #516
# artist id:  7xT0arvCDupDU1YYy0BNv9
# Processing track #517
# artist id:  4WnAHZz1pgl8hus8hidIRV
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# Processing track #518
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# Processing track #519
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# Processing track #520
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# Processing track #521
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# Processing track #522
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# Processing track #523
# artist id:  0OQeMFqoRD5clB0cPYVbxY
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# Processing track #524
# artist id:  0oNrNJk1WEVKDpbz4bw54T
# genres = []
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# Processing track #525
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# artist id:  1bj5GrcLom5gZFF5t949Xl
# Processing track #526
# artist id:  1bj5GrcLom5gZFF5t949Xl
# artist id:  0VVnWF3KNaa5O7ESohKhAx
# Processing track #527
# artist id:  041iTeoMIwXMlShuQPIVKo
# Processing track #528
# artist id:  3MyFDtqB80WZvbtCZRsekM
# Processing track #529
# artist id:  3MyFDtqB80WZvbtCZRsekM
# Processing track #530
# artist id:  3MyFDtqB80WZvbtCZRsekM
# Processing track #531
# artist id:  6AC7fqQQgNwXXpBa5bqyBr
# genres = []
# artist id:  6kpYdtbD0QinjBcwkxLPm3
# artist id:  3MyFDtqB80WZvbtCZRsekM
# Processing track #532
# artist id:  3MyFDtqB80WZvbtCZRsekM
# Processing track #533
# artist id:  3MyFDtqB80WZvbtCZRsekM
# Processing track #534
# artist id:  4a9sClW4YpYQE5jUMAWx5W
# artist id:  5VOokbPJRb3e8tJYMxxsMQ
# genres = []
# Processing track #535
# artist id:  4a9sClW4YpYQE5jUMAWx5W
# Processing track #536
# artist id:  6gK1Uct5FEdaUWRWpU4Cl2
# Processing track #537
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #538
# artist id:  0cmWgDlu9CwTgxPhf403hb
# artist id:  6FUsQ3dkSd27KwQ1iCugSV
# Processing track #539
# artist id:  0cmWgDlu9CwTgxPhf403hb
# artist id:  1mmKns9q559kAZeHbKeAu2
# genres = []
# Processing track #540
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #541
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #542
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #543
# artist id:  0cmWgDlu9CwTgxPhf403hb
# artist id:  2AcUPzkVWo81vumdzeLLRN
# Processing track #544
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #545
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #546
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #547
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #548
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #549
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #550
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #551
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #552
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #553
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #554
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #555
# artist id:  7vk5e3vY1uw9plTHJAMwjN
# artist id:  6JkBbOaS3boYr0jIeSj5eM
# genres = []
# Processing track #556
# artist id:  3YRLUjgMJ1xg1TIcknIxlv
# Processing track #557
# artist id:  6p31dmLI4jnatyEQmrVPDc
# artist id:  11i3tISGuOUmWFuXTRNrtD
# Processing track #558
# artist id:  4BaLB5aiExO29BEGVUisru
# Processing track #559
# artist id:  5mMkUZv8uUrlH0SHX89BeS
# Processing track #560
# artist id:  5ZMwoAjeDtLJ0XRwRTgaK8
# Processing track #561
# artist id:  6rdTxNwQhUJTodUx7voWXO
# artist id:  4qxDuHrnTYQkihZiJYLWdy
# Processing track #562
# artist id:  51qUDJb5AtQX6jIL4VJx6M
# Processing track #563
# artist id:  4eFImh8D3F15dtZk0JQlpT
# artist id:  2970BxpdOBQmkMit6i9kVF
# Processing track #564
# artist id:  0R7kz98b2zjiuU3AffoeYz
# Processing track #565
# artist id:  4BaLB5aiExO29BEGVUisru
# artist id:  4k0LkFZ2MbY3Cs5PrjsFX8
# genres = []
# Processing track #566
# artist id:  6PuOeFpvcL6TYcRmEJKbdw
# Processing track #567
# artist id:  1vL80BIxkjefhlD5Gc88r5
# Processing track #568
# artist id:  1IdkKQ9CM1i0wygfxYV4Z3
# artist id:  1I7FVmvisCtSFzmm87mbLR
# Processing track #569
# artist id:  4MismZLKqMb2Qb2HjK4sdE
# Processing track #570
# artist id:  2iAq0gKjg6badqGMiOfwrK
# genres = []
# artist id:  6BIBBG2t4XviEM2XfnNAUd
# genres = []
# Processing track #571
# artist id:  5rCiWGekLiXuAdWJsKdQEN
# genres = []
# Processing track #572
# artist id:  6PuOeFpvcL6TYcRmEJKbdw
# Processing track #573
# artist id:  1IaccfV9FzIR8Iax4cZ5Fn
# Processing track #574
# artist id:  1xQVwAdSzsF8DO76NsZpMK
# Processing track #575
# artist id:  5DZr9dQj9KPd62WuMeIPqK
# Processing track #576
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #577
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #578
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #579
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #580
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #581
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #582
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #583
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #584
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #585
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #586
# artist id:  4eFImh8D3F15dtZk0JQlpT
# artist id:  67xyhWIvYQK5qr6b0gElst
# Processing track #587
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #588
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #589
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #590
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #591
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #592
# artist id:  4eFImh8D3F15dtZk0JQlpT
# artist id:  6jOzYw2JWxujmMIwwiAaEA
# genres = []
# Processing track #593
# artist id:  38WRvRXIOeefhY4vRxEGrr
# Processing track #594
# artist id:  6kLrAuoxxTyDRY3k9Je0bp
# artist id:  1OWiZw4DbyqYtwl4klKOlJ
# genres = []
# Processing track #595
# artist id:  4wzvXCxUnFdUjNgTwqPOf3
# artist id:  6K2D6lHehkLagzmMKgYc9V
# genres = []
# Processing track #596
# artist id:  4J4jrBN4VwLUYCrZ0I0L69
# genres = []
# artist id:  5aweKNLI0ZyI48q5TmoCxT
# Processing track #597
# artist id:  49qnSNt8EO6ppsKVddyInS
# artist id:  1I7FVmvisCtSFzmm87mbLR
# Processing track #598
# artist id:  1xQVwAdSzsF8DO76NsZpMK
# Processing track #599
# artist id:  2gR0iQTVBPHDKiNn1Kq8HI
# artist id:  01COhV6E3zLbPa5IJ27XkL
# genres = []
# Could not find related genres for artist: 01COhV6E3zLbPa5IJ27XkL
# Processing track #600
# artist id:  3T2iIPbvIyKJdXNrFYiYXn
# Processing track #601
# artist id:  4iZlSQSRIZ5HYEwwcfbR0c
# genres = []
# Processing track #602
# artist id:  1KRBEKFSXdm2SkeIn5VAIn
# Processing track #603
# artist id:  3Muhm9HEowEpdC0i6NuW3P
# Processing track #604
# artist id:  47i4lPow1dIRwOb85AB6lj
# Processing track #605
# artist id:  3YdYc0Ewo5Vpejw0r3dV74
# Processing track #606
# artist id:  6puT1BjHML5msBxFGsJywF
# Processing track #607
# artist id:  2D38buglrcCl9TMZ45tkh1
# artist id:  0kCjEfr9S7eFKUlYQTo38f
# genres = []
# Could not find related genres for artist: 0kCjEfr9S7eFKUlYQTo38f
# Processing track #608
# artist id:  79OTUKSZMGMmmR32RWG2ig
# Processing track #609
# artist id:  4VNKVCluxMcjqwYJm3yuQ3
# Processing track #610
# artist id:  36C73GYwgP8rqwCjUyswoS
# Processing track #611
# artist id:  4Lu4jDj4ky1wxvRDgL90tc
# genres = []
# Processing track #612
# artist id:  4VNKVCluxMcjqwYJm3yuQ3
# Processing track #613
# artist id:  2FiTalpUBZuzQL2lwl1Z9g
# Processing track #614
# artist id:  0Tm39XjMaHN8dANIBqae1T
# Processing track #615
# artist id:  5S99ZV4z8f1cQpoqm22ZB9
# Processing track #616
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #617
# artist id:  06n2rDm62tW55l6cZEL15r
# Processing track #618
# artist id:  4M6AbBFPTNgnATQ7UCNEWk
# genres = []
# artist id:  3gkk18CqFxsmkZkGyYZKqo
# artist id:  1I7FVmvisCtSFzmm87mbLR
# Processing track #619
# artist id:  4uJmyKMSQLJhB0gN5CAmSG
# artist id:  4FpztPnncQBkAH7jRu2HNv
# Processing track #620
# artist id:  6lK8O3kyFThiTmgowQZGOH
# Processing track #621
# artist id:  1I7FVmvisCtSFzmm87mbLR
# Processing track #622
# artist id:  6R7amlI5rHTNVDpOnldyfT
# Processing track #623
# artist id:  0Jvij1QzxELMyq0uppP2OG
# artist id:  4L3uym0nDz6ziBGFOmUCDu
# artist id:  6zfwxQQjoCU9uSsrwckyZv
# Processing track #624
# artist id:  7qqEqY1pR6Uj2Z41HNuszd
# Processing track #625
# artist id:  2gR0iQTVBPHDKiNn1Kq8HI
# Processing track #626
# artist id:  0R7kz98b2zjiuU3AffoeYz
# Processing track #627
# artist id:  0OltT51j3hIkgaDJqqPzDn
# artist id:  321BLMRzhTIVWwgvuIJWuO
# genres = []
# Could not find related genres for artist: 321BLMRzhTIVWwgvuIJWuO
# Processing track #628
# artist id:  1PryMSya1JnSAlcwYawCxp
# Processing track #629
# artist id:  24XZ9joYiC4hzMYXihqgc1
# Processing track #630
# artist id:  7GmnD2XZleQw8PPzRJV7FY
# Processing track #631
# artist id:  02VSzyVA68par8UGNNRbAN
# artist id:  2vplyVvtElnBqkZuftPVow
# Processing track #632
# artist id:  30J2BZr9IIoch7Sj47xtpD
# genres = []
# artist id:  0EmioUrT5ZIveHOQnDcTGM
# Processing track #633
# artist id:  0YC192cP3KPCRWx8zr8MfZ
# Processing track #634
# artist id:  0YC192cP3KPCRWx8zr8MfZ
# Processing track #635
# artist id:  0YC192cP3KPCRWx8zr8MfZ
# Processing track #636
# artist id:  0YC192cP3KPCRWx8zr8MfZ
# Processing track #637
# artist id:  0YC192cP3KPCRWx8zr8MfZ
# Processing track #638
# artist id:  0YC192cP3KPCRWx8zr8MfZ
# Processing track #639
# artist id:  0YC192cP3KPCRWx8zr8MfZ
# Processing track #640
# artist id:  6E8vZ5lkpXbXlkgHhbVJSl
# Processing track #641
# artist id:  7qqEqY1pR6Uj2Z41HNuszd
# Processing track #642
# artist id:  3yJyh0YZiJPo3ZBNkw1Ayh
# Processing track #643
# artist id:  4zygNhOWWhflJVjoHMul6K
# Processing track #644
# artist id:  1Dt1UKLtrJIW1xxRBejjos
# Processing track #645
# artist id:  7qqEqY1pR6Uj2Z41HNuszd
# Processing track #646
# artist id:  46pzwQbaXoRtHMvl1NtIwB
# artist id:  6AHDMBhI1OTokvO5DkBB9p
# artist id:  1I7FVmvisCtSFzmm87mbLR
# Processing track #647
# artist id:  5T1PVwkHZgpykOrDmM2ldD
# artist id:  7iSCeXzx1X2I0bSgQtbfCD
# Processing track #648
# artist id:  0FvSMtCS6UPO4dfsvFT4Vm
# artist id:  2wNRj72waNbqPsa3RvJ6yQ
# artist id:  1y71H4hNtnHG7LeU1Y47FO
# artist id:  6aDX1jzNVAI9enlQzW0Pgw
# artist id:  0O98jlCaPzvsoei6U5jfEL
# artist id:  5BjDMxlaiYzs3qbi4wVbeL
# ...
# artist id:  4M6YdvdCPW1fvQYbLwmNWZ
# Processing track #2014
# artist id:  3CgMjC9kBPZPgUZEmcjsnU
# genres = []
# Processing track #2015
# artist id:  6J12Ff7swWdQ7CslETtKBT
# Processing track #2016
# artist id:  4BlBvAGQrqv3vWmx8GWTds
# Processing track #2017
# artist id:  24OmLPZEq6dYiGJbPCAFVm
# Processing track #2018
# artist id:  6E8vZ5lkpXbXlkgHhbVJSl
# artist id:  2mOHlObkV2dhspvDzllGOS
# genres = []
# Processing track #2019
# artist id:  0OltT51j3hIkgaDJqqPzDn
# artist id:  321BLMRzhTIVWwgvuIJWuO
# genres = []
# Could not find related genres for artist: 321BLMRzhTIVWwgvuIJWuO
# Processing track #2020
# artist id:  5KEmdf3GZJMTtVb74Klhy1
# genres = []
# artist id:  25YPY0NKDJMmhXXPKzb4OP
# genres = []
# Could not find related genres for artist: 25YPY0NKDJMmhXXPKzb4OP
# Processing track #2021
# artist id:  1I7FVmvisCtSFzmm87mbLR
# artist id:  1yBSX25jjXRF6KqAKGygy2
# Processing track #2022
# artist id:  1CHnBSP2xS4bRyHRenc5aO
# Processing track #2023
# artist id:  52pEvBJxxzBacaaxVOSyxa
# artist id:  5Ln6VxkwRDdAH40Lel6Yj8
# genres = []
# Processing track #2024
# artist id:  1I7FVmvisCtSFzmm87mbLR
# artist id:  4gJkcE85yauN8vUrt8bIFT
# genres = []
# Processing track #2025
# artist id:  5cVZnnikhcTwPENYemDKF6
# artist id:  3Nc4dbxJUlEmftLhLuXn3O
# Processing track #2026
# artist id:  0OltT51j3hIkgaDJqqPzDn
# Processing track #2027
# artist id:  2ovmrverobmQvD14n5REoU
# artist id:  7AvmkZAE1JYnkVXJAT4SEC
# genres = []
# Could not find related genres for artist: 7AvmkZAE1JYnkVXJAT4SEC
# Processing track #2028
# artist id:  5cVZnnikhcTwPENYemDKF6
# artist id:  7FNBqkMNkiNpP5w9WY4WHQ
# Processing track #2029
# artist id:  3VUqC0Q4XHN2PBuFQeredd
# artist id:  5cVZnnikhcTwPENYemDKF6
# Processing track #2030
# artist id:  5A7ayYKcSsydP31DqS4vQW
# Processing track #2031
# artist id:  7IMSmMHDPpZL0ZjOr8ssOj
# genres = []
# Processing track #2032
# artist id:  69lVKiR03uaDrGqEgOC2gu
# genres = []
# Processing track #2033
# artist id:  2XE7Kskh4TLEcxIyNSoCwN
# artist id:  2DpGG0b6Rt9q69o8Rk1DCa
# Processing track #2034
# artist id:  1uO4ut3M0hYeCfEEUdFnEp
# genres = []
# Processing track #2035
# artist id:  0oaRcSFPFh6FaAgZjSVYfr
# genres = []
# Processing track #2036
# artist id:  1oobYLromCfJh2nx8pfZiI
# Processing track #2037
# artist id:  1uO4ut3M0hYeCfEEUdFnEp
# genres = []
# Processing track #2038
# artist id:  29osCpAsrEiHxE8t6khiJr
# artist id:  37nAYWCcjUzCtswtd9F0Na
# genres = []
# Processing track #2039
# artist id:  3DtnSKmpjFGUzZcccWfG43
# Processing track #2040
# artist id:  1RTVukXrK45mKMIVFFEMM0
# Processing track #2041
# artist id:  4Rj2COYs5hQsw8rYIxSviz
# Processing track #2042
# artist id:  4zAOqBfNLyWFvj1e3yvypJ
# Processing track #2043
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #2044
# artist id:  4PfXiTCDXTYEobjXjcRFNW
# Processing track #2045
# artist id:  7zrkALJ9ayRjzysp4QYoEg
# Processing track #2046
# artist id:  2mLA48B366zkELXYx7hcDN
# Processing track #2047
# artist id:  2kLa7JZu4Ijdz1Gle2khZh
# Processing track #2048
# artist id:  1CuE092UR0MnsGFKEHZNgC
# Processing track #2049
# artist id:  2Y4VeDUhZAE8UfGXqZJ7dX
# artist id:  3rd5aojNBopxBjaZdoLOrb
# Processing track #2050
# artist id:  6c4PFTwVucnE0A6l219i99
# Processing track #2051
# artist id:  6MTByljF8u5omBltY2VKPU
# Processing track #2052
# artist id:  07dLDdQaGtCzRksu1phXbG
# Processing track #2053
# artist id:  4C4wNUmOrOgXWI3S3twrl4
# Processing track #2054
# artist id:  446utY1mJlK59YfxCqWosV
# Processing track #2055
# artist id:  4M7kyBSGHK0aYYjObYeRXZ
# artist id:  30mOz7SQsfk9JgyD6HporM
# genres = []
# Processing track #2056
# artist id:  5UefiThiZ352HWMOgZvOhx
# Processing track #2057
# artist id:  5RpRyZqqxZjQA8f5a1JU8z
# genres = []
# artist id:  1I7FVmvisCtSFzmm87mbLR
# Processing track #2058
# artist id:  36C73GYwgP8rqwCjUyswoS
# Processing track #2059
# artist id:  5Uy8Skuxzxf38jMDTndKIU
# Processing track #2060
# artist id:  52qbMkeZq79cVYB6RqLQ98
# Processing track #2061
# artist id:  3QSCLYXV7vTFADgtFr35Sn
# genres = []
# Processing track #2062
# artist id:  4dOyKMeKD8DPTC2qn0bwk7
# Processing track #2063
# artist id:  0vdtQahAxzU1jvuyer6ppS
# Processing track #2064
# artist id:  2laFwNRffMM18LvKKDxCs9
# Processing track #2065
# artist id:  4aiPhj5s76v2lTErhRnB7A
# artist id:  24OmLPZEq6dYiGJbPCAFVm
# Processing track #2066
# artist id:  4Lu4jDj4ky1wxvRDgL90tc
# genres = []
# Processing track #2067
# artist id:  7JspAYeHr3STh01aVwXmFE
# Processing track #2068
# artist id:  3FvZelhwzd1MU4ZqfDTcSC
# Processing track #2069
# artist id:  4dktzc5hWsQPqmovObGZIG
# artist id:  1496XxkytEk26FUJLfpVZr
# Processing track #2070
# artist id:  2dUsAHSrnsFvNpNpAV4aGI
# Processing track #2071
# artist id:  4F2bvUKla5F5A87lciL1Td
# Processing track #2072
# artist id:  1jV6ZVJ5WPoWiYZfOolQV6
# genres = []
# Processing track #2073
# artist id:  1YFLNH4rO40x9i16RpLwdY
# genres = []
# Processing track #2074
# artist id:  28QIgdCMLnz3ZBkFRCkD5h
# Processing track #2075
# artist id:  51CANyDEIfgYt0mwLKCpZ6
# Processing track #2076
# artist id:  3sb3yLRnhW2L2ulU93eKfl
# Processing track #2077
# artist id:  2dUsAHSrnsFvNpNpAV4aGI
# Processing track #2078
# artist id:  697YONfQhe3i1GqsGVJIgn
# Processing track #2079
# artist id:  48sX8BqvRZLrpwyXGy8wkv
# Processing track #2080
# artist id:  2X2gALerQqdAArPBOdIIiJ
# artist id:  4v0WMhBA3YDeadQ6PqA3Yy
# genres = []
# Processing track #2081
# artist id:  5r2JG9bxzdaGLiu4cq9X9t
# Processing track #2082
# artist id:  2r7acJfhCrsNO9ZGbUmEsS
# genres = []
# Processing track #2083
# artist id:  1Pe3z1UqRzKsQtHsl25dm6
# Processing track #2084
# artist id:  6a4cdntqTPN10fph5A8zRQ
# Processing track #2085
# artist id:  11kBu957KTYoAltZHDm8gW
# Processing track #2086
# artist id:  2laFwNRffMM18LvKKDxCs9
# Processing track #2087
# artist id:  6V46XOVfnoCXHWBeZ92k5b
# genres = []
# Processing track #2088
# artist id:  6CFWXwqEBUi0UFoIIxmg9h
# artist id:  4Lu4jDj4ky1wxvRDgL90tc
# genres = []
# artist id:  4ZdJ35EaWtMCvdbczspFET
# genres = []
# Processing track #2089
# artist id:  7JksKqLDuYE8QYj2WjiNQr
# Processing track #2090
# artist id:  3zFDFDCqO5UONM9pxVsVqh
# Processing track #2091
# artist id:  1WjBIvYAnZTkTh5UiZNwlR
# Processing track #2092
# artist id:  4eFImh8D3F15dtZk0JQlpT
# Processing track #2093
# artist id:  4yyre4wV5as2rW3k0gekFA
# Processing track #2094
# artist id:  4TFmgYfhLJxF6nL8WDSnWV
# Processing track #2095
# artist id:  5S99ZV4z8f1cQpoqm22ZB9
# Processing track #2096
# artist id:  1CsZ0ihKPWBDUERlQt8ekr
# Processing track #2097
# artist id:  1CsZ0ihKPWBDUERlQt8ekr
# Processing track #2098
# artist id:  3ZZ9BwdWrBRhqNOvJ2ODNd
# Processing track #2099
# artist id:  1dP9LSI5cbBvExw1lG0jlM
# artist id:  67AN4lugn8LGCC1ICziKY6
# Processing track #2100
# artist id:  3Epc9q8xwUr2WVYmAxOrBe
# Processing track #2101
# artist id:  0OltT51j3hIkgaDJqqPzDn
# artist id:  59SOW7UtdIt5yRxmlilb4p
# genres = []
# Could not find related genres for artist: 59SOW7UtdIt5yRxmlilb4p
# Processing track #2102
# artist id:  3kI19T2Y7mzINNIOGHTg5P
# Processing track #2103
# artist id:  0FtVISUJUZSWPU4LGeovTM
# Processing track #2104
# artist id:  5gGcNiVa7VMb9sPxKB03Pq
# genres = []
# Processing track #2105
# artist id:  6h2EcimpzT4Ft2t2vfjEt4
# artist id:  3rVvL036o05Y34SPRsW63P
# Processing track #2106
# artist id:  6wuypXdcEp8ZS7cWmCp1FO
# genres = []
# Could not find related genres for artist: 6wuypXdcEp8ZS7cWmCp1FO
# Processing track #2107
# artist id:  5If5Tdg66Q5X3L57G7A6Pn
# artist id:  4y0Bho33I93MMxrgsRwMOj
# Processing track #2108
# artist id:  3kI19T2Y7mzINNIOGHTg5P
# Processing track #2109
# artist id:  5G7dwcHN2RE0qHVUkJjoEz
# genres = []
# Processing track #2110
# artist id:  6gK1Uct5FEdaUWRWpU4Cl2
# Processing track #2111
# artist id:  0Upbj4hHk4d4UJ0HhnVs4F
# Processing track #2112
# artist id:  1GL8uwuoUqjDP9Qs37FoFG
# genres = []
# Processing track #2113
# artist id:  0Vox2K7dpTsHq004KMQiuJ
# genres = []
# Processing track #2114
# artist id:  1GL8uwuoUqjDP9Qs37FoFG
# genres = []
# Processing track #2115
# artist id:  6eVy5h7mbP75HUsAnnxcBv
# genres = []
# Processing track #2116
# artist id:  7sF8RuNYCpGngojCFcHAv4
# artist id:  72TD3r8reGeogwogAJw01w
# genres = []
# Processing track #2117
# artist id:  4TFmgYfhLJxF6nL8WDSnWV
# Processing track #2118
# artist id:  5EEbMGQOwrTuy51Vin8bL1
# Processing track #2119
# artist id:  0wgemfQJai9SWvF53YcMIT
# Processing track #2120
# artist id:  26BL0aeVS96sje8JfCNfUk
# artist id:  4aWAHyYMQDL2sAZaCsd9d1
# artist id:  7DBqQRhNbhTOu3hDO0XE8Q
# genres = []
# artist id:  33Y65pjZqILshMnkWzoUzl
# genres = []
# Could not find related genres for artist: 33Y65pjZqILshMnkWzoUzl
# Processing track #2121
# artist id:  5wDUccrtIJwwjOtqed0FrW
# Processing track #2122
# artist id:  62RdOEwjfXjFOQpKdufMR7
# Processing track #2123
# artist id:  5XltDnmtnK6URPuoLtYF0A
# Processing track #2124
# artist id:  0m5XJwKGYyUjd3VMfcINCQ
# Processing track #2125
# artist id:  3LbMrfAq8YnMksyS3H5zWD
# genres = []
# Processing track #2126
# artist id:  6dZdcowBonykRqLdlfb7qR
# Processing track #2127
# artist id:  1CHnBSP2xS4bRyHRenc5aO
# Processing track #2128
# artist id:  23BtKJexFLn0Ri6s7BEC4d
# artist id:  5Fdoc9ZBntFbRvSklB2BqZ
# genres = []
# Processing track #2129
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #2130
# artist id:  4DkYxtaASIKQnk4Gj0TB7k
# Processing track #2131
# artist id:  44MlmhbFGLUIUPEqEgcLaL
# Processing track #2132
# artist id:  3KtaBB3asBs44O4h3xx2V0
# Processing track #2133
# artist id:  7Bv1SZbrpTYQixKfQgCzsI
# Processing track #2134
# artist id:  4e0hkGJ86D7I16d4vBnx3j
# Processing track #2135
# artist id:  52qnChybMeZVRp2wkEkJEx
# genres = []
# Processing track #2136
# artist id:  7birWEa67r8nIby8rV64EJ
# genres = []
# Processing track #2137
# artist id:  7vByi0TCh4wNTdqNK7dNqe
# Processing track #2138
# artist id:  3AihmaPi9Wr3O7z578f6mH
# Processing track #2139
# artist id:  21mKp7DqtSNHhCAU2ugvUw
# Processing track #2140
# artist id:  7xjpPNWngnYl57VxpnbakE
# Processing track #2141
# artist id:  0i3rXQVnr4SE5pl3qtBM2o
# Processing track #2142
# artist id:  0i3rXQVnr4SE5pl3qtBM2o
# Processing track #2143
# artist id:  0i3rXQVnr4SE5pl3qtBM2o
# Processing track #2144
# artist id:  4Na15qor3lla58lkeQet8D
# Processing track #2145
# artist id:  3V3T5haMWZGfFxqVsAB9oB
# Processing track #2146
# artist id:  0K1lHu1BP65Z1DErnljxUw
# Processing track #2147
# artist id:  75DsjkCdxGmvitG1tqqBkL
# Processing track #2148
# artist id:  5vo3SAsS0EuZTW7QkGy0Xs
# Processing track #2149
# artist id:  0m5XJwKGYyUjd3VMfcINCQ
# Processing track #2150
# artist id:  38DX4hQVvPBs3PThDIAK11
# artist id:  283luElKuBFBJhVzDzZk9y
# genres = []
# Could not find related genres for artist: 283luElKuBFBJhVzDzZk9y
# Processing track #2151
# artist id:  4qjTbJHr1i0O0ViKgFgZqN
# Processing track #2152
# artist id:  0ZfeJXXkQPkG21bGk3NTLt
# Processing track #2153
# artist id:  0cmWgDlu9CwTgxPhf403hb
# Processing track #2154
# artist id:  32ogthv0BdaSMPml02X9YB
# artist id:  4sSSkVtrCTzENCgm2vokiY
# Processing track #2155
# artist id:  3gNEIgLeknpwkNViU8WAhg
# artist id:  4BaLB5aiExO29BEGVUisru
# Processing track #2156
# artist id:  5oOhM2DFWab8XhSdQiITry
# Processing track #2157
# artist id:  4dTw5svKFBPnfijbi3H9eI
# Processing track #2158
# artist id:  1Bs9FqmJBHrAJN6DLFIPt1
# Processing track #2159
# artist id:  5j3iObqG7iT7utWpTTmC7F
# artist id:  2gvllqEZ8dnt6OYL50GC7b
# genres = []
# Could not find related genres for artist: 2gvllqEZ8dnt6OYL50GC7b
#                   spotify_id  \
# 0     1gr3wnx384k5kcQAs2S1FA
# 1     4qzIWW9yArNdpuqc9SbtJH
# 2     1y9KCKHJq5Wy8JTOUKy5O1
# 3     3uI33EsE7AVM3GMxaOn7fv
# 4     6f8gNNCNSveUl4gxt7tzp0
# ...                      ...
# 2155  4cIDajUp2dMjKiDmDvFDg8
# 2156  2wqyAaRNAZBO9OncYwAQSR
# 2157  1jHSmrYPQsr5qGRxLmEQ52
# 2158  6Vhtb9RU1thtzBcsy3bI9q
# 2159  03FcCV2h88qkjuhTaEB5Zh
#
#                                                   title  \
# 0                                               memphis
# 1                                              Floating
# 2                                                Malaga
# 3                                               Alabora
# 4     Light Of Day (feat. Ólafur Arnalds) - Parra fo...
# ...                                                 ...
# 2155                      Tarlabasi - Be Svendsen Remix
# 2156                               Japan (Instrumental)
# 2157                                   Tuur mang Welten
# 2158                                      Dance of Kali
# 2159                    For What It's Worth (India Dub)
#
#                                        artists  \
# 0                          [Remy Van Kesteren]
# 1                                       [Klur]
# 2                                    [Boztown]
# 3                                    [Beyhude]
# 4     [ODESZA, Parra for Cuva, Ólafur Arnalds]
# ...                                        ...
# 2155         [Oceanvs Orientalis, Be Svendsen]
# 2156                                   [Tycho]
# 2157                        [Niklas Paschburg]
# 2158                             [Prem Joshua]
# 2159                   [DJ Drez, Joey Lugassy]
#
#                                              artists_id  \
# 0                              [5x183GdNFhX9FETwGNpOZE]
# 1                              [5Y1YwWzFX7BIxBbdAOXOEJ]
# 2                              [49CZw9qooXeYTWKe9ioZPx]
# 3                              [65orViGnlMcbptdIGceZzo]
# 4     Kp7DqtSNHhCAU2ugvUw, 238y1dKPtMeFEpX3Y6H1V...
# ...                                                 ...
# 2155   [3gNEIgLeknpwkNViU8WAhg, 4BaLB5aiExO29BEGVUisru]
# 2156                           [5oOhM2DFWab8XhSdQiITry]
# 2157                           [4dTw5svKFBPnfijbi3H9eI]
# 2158                           [1Bs9FqmJBHrAJN6DLFIPt1]
# 2159   [5j3iObqG7iT7utWpTTmC7F, 2gvllqEZ8dnt6OYL50GC7b]
#
#                                                  genres  popularity  energy  \
# 0                                      [classical harp]          34   0.694
# 1                                   [progressive house]          60   0.671
# 2                                [hip-hop experimental]          46   0.592
# 3     [ethnotronica, organic electronic, organic house]          58   0.485
# 4     [bow pop, chillwave, compositional ambient, do...          51   0.868
# ...                                                 ...         ...     ...
# 2155  [deep euro house, ethnotronica, organic electr...          53   0.599
# 2156  [chillwave, downtempo, electronica, indietroni...          22   0.433
# 2157             [compositional ambient, neo-classical]           0   0.348
# 2158              [indian fusion, kirtan, world fusion]           0   0.697
# 2159                  [high vibe, kirtan, world fusion]           0   0.577
#
#       valence  danceability  acousticness  loudness  speechiness  \
# 0      0.4170         0.466       0.67000   -15.459       0.0440
# 1      0.0763         0.706       0.07900   -12.190       0.0391
# 2      0.4350         0.624       0.00029   -10.239       0.0266
# 3      0.0830         0.653       0.80800   -14.745       0.0371
# 4      0.0385         0.700       0.06300    -8.097       0.0378
# ...       ...           ...           ...       ...          ...
# 2155   0.2160         0.854       0.20600   -12.259       0.0604
# 2156   0.3400         0.562       0.21900   -12.291       0.0323
# 2157   0.2610         0.290       0.96600   -16.575       0.0437
# 2158   0.4870         0.614       0.02590    -8.212       0.0322
# 2159   0.5740         0.725       0.06430    -7.859       0.0307
#
#       instrumentalness  liveness    tempo  key  mode  time_signature  \
# 0               0.8390    0.1040  199.963    4     0               4
# 1               0.8720    0.1020  120.002    1     1               4
# 2               0.5350    0.3420   88.062    5     0               4
# 3               0.9390    0.1150  110.002    2     0               4
# 4               0.5070    0.1510  115.005    6     0               4
# ...                ...       ...      ...  ...   ...             ...
# 2155            0.8610    0.0899  114.001    4     0               4
# 2156            0.7980    0.3860  166.036    0     1               4
# 2157            0.8560    0.3710  179.919    1     0               3
# 2158            0.0897    0.0575  154.995    8     1               4
# 2159            0.8510    0.1000   95.011    9     1               4
#
#       duration_ms
# 0          194027
# 1          252552
# 2          145225
# 3          423756
# 4          273624
# ...           ...
# 2155       545813
# 2156       374569
# 2157       277597
# 2158       511200
# 2159       296653
#
# [2160 rows x 19 columns]

# %%
# number of tracks with no genres
(~df['genres'].astype(bool)).sum()  # empty lists translate to False as a boolean
# Out:
# 6

# %%
# show tracks without genres
no_genres = ~df['genres'].astype(bool)
df[no_genres]
# Out:
#                   spotify_id                  title          artists  \
# 357   4NHeCNltciImyZexSMNRwc       Mobiagse - Mixed  [Ulf Alexander]
# 1056  0UwcqaMHoBRbCKFj2NZ2AC                 Dancar        [REA SOM]
# 1214  3XRkMJIgAOGMoB5wlptXaC      House of Illusion          [SONNY]
# 1312  7KbA07FXaTcl6CZ63J9AdI        Forever Walking       [Max Weis]
# 1408  3HxQsBASZPsg3FUIpeGdE5  Souls of Sorrow (555)           [Paya]
# 1411  1c32e7sA6sxY5GmOxvn7ya          Spirit Voices          [Karam]
#
#                     artists_id genres  popularity  energy  valence  \
# 357   [64MJxMlRak8Xgh3N9vePD1]     []           0   0.611    0.132
# 1056  [7jgK8I3O10R3QKxxGS9WJ7]     []           2   0.598    0.684
# 1214  [7woO5xoM5KGReQEEqdexGj]     []           0   0.754    0.692
# 1312  [3MYl2oyRRRieXiROUzhE3z]     []           0   0.428    0.228
# 1408  [21KKHztU2Tpix1EFOg7xBI]     []           4   0.711    0.237
# 1411  [6sb4xnx2GsiNxIx4A4kjDm]     []           2   0.488    0.385
#
#       danceability  acousticness  loudness  speechiness  instrumentalness  \
# 357          0.847        0.0274   -12.289       0.0996          0.485000
# 1056         0.777        0.7390   -12.490       0.0974          0.000079
# 1214         0.478        0.0224   -10.807       0.0432          0.532000
# 1312         0.758        0.1790   -11.706       0.0793          0.589000
# 1408         0.712        0.2040    -8.781       0.0648          0.400000
# 1411         0.679        0.1250   -11.200       0.0497          0.908000
#
#       liveness    tempo  key  mode  time_signature  duration_ms
# 357     0.0979  122.010    4     0               4       424918
# 1056    0.0998  111.068   10     0               4       212440
# 1214    0.3350  181.966    4     0               4       528941
# 1312    0.3000  120.001    7     0               4       285161
# 1408    0.1650  100.007    7     1               4       355200
# 1411    0.1240  105.000    7     1               4       329875

# %%
# Check if there is any missing values
df.isnull().values.any()
# Out:
# False

# %%
# Save all the data
df.to_csv('../Data/csv/01_spotify_data_(all).csv')  # For visualization
df.to_pickle('../Data/pkl/01_spotify_data_(all).pkl')  # for backup


# Save apart the tracks without genres fron the complete ones
df[no_genres].to_pickle('../Data/pkl/01_spotify_data_(isna).pkl')
df[~no_genres].to_pickle('../Data/pkl/01_spotify_data_(notna).pkl')
